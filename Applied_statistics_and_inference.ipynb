# %%
#1.What are type1 and type 2 errors in hypothesis testing and how do they impact decision making.
'''Type 1 error is when we reject the null hypothesis when it is actually true. Type 2 error is when we fail to reject the null hypothesis when it is actually false
and accept the alternative hypothesis.'''
# Out:
# 'Type 1 error is when we reject the null hypothesis when it is actually true. Type 2 error is when we fail to reject the null hypothesis when it is actually false \nand accept the alternative hypothesis.'

# %%
#2 What is the P- value in hypothesis testing and how should it be interpreted in the context of the null hypothesis.
'''The P-value is the probability of obtaining a test statistic at least as extreme as the one observed, assuming that the null hypothesis is true.
In hypothesis testing, the P-value is used to determine whether to reject or fail to reject the null HYPOTHESIS.'''
# Out:
# 'The P-value is the probability of obtaining a test statistic at least as extreme as the one observed, assuming that the null hypothesis is true.\nIn hypothesis testing, the P-value is used to determine whether to reject or fail to reject the null HYPOTHESIS.'

# %%
#3 Explain the difference Z-test and a T-test,including when to use each.
'''Z-test is used when the population standard deviation is known and the sample size is large.
T-test is used when the population standard deviation is unknown and the sample size is small.'''
# Out:
# 'Z-test is used when the population standard deviation is known and the sample size is large.\nT-test is used when the population standard deviation is unknown and the sample size is small.'

# %%
#4 What is confidence interval and how does the margin of error influence its width and interpretation.
'''Confidence interval is a range of values that is likely to contain the true population parameter with a certain level of confidence.
It is calculated by taking a sample from the population and using it to estimate the population parameter.'''
# Out:
# 'Confidence interval is a range of values that is likely to contain the true population parameter with a certain level of confidence.\nIt is calculated by taking a sample from the population and using it to estimate the population parameter.'

# %%
#5 Describe the purpose and assumptions of an ANOVA test.How does it extend hypothesis testing to more than two groups.
'''The purpose of an ANOVA test is to determine whether there are significant differences between the means of two or more groups.
It assumes that the data is normally distributed and that the variances of the groups are equal.
It extends hypothesis testing to more than two groups by comparing the means of all groups to a single group.'''
# Out:
# 'The purpose of an ANOVA test is to determine whether there are significant differences between the means of two or more groups.\nIt assumes that the data is normally distributed and that the variances of the groups are equal.\nIt extends hypothesis testing to more than two groups by comparing the means of all groups to a single group.'

# %%
#6 Write a python program to perform a one-sample Z-test and interpret the result for a given dataset.
'''python
import scipy.stats as stats
import numpy as np
data = np.array([1,2,3,4,5])
z_stat,p_value=stats.ztest(data,value=null_mean)
if p_value<0.05:
    print("reject null hypothesis")
    else:
        print("fail to reject null hypothesis")'''
# Out:
# 'python\nimport scipy.stats as stats\nimport numpy as np\ndata = np.array([1,2,3,4,5])\nz_stat,p_value=stats.ztest(data,value=null_mean)\nif p_value<0.05:\n    print("reject null hypothesis")\n    else:\n        print("fail to reject null hypothesis")'

# %%
#7 Simulate a dataset from a binomial distribution (n=10,p=0.5) using Numpy and plot the histogram.
'''python
import numpy as np
import matplotlib.pyplot as plt
n=10
p=0.5
x=np.random.binomial(n,p,1000)
plt.hist(x,bins=10)
plt.show()'''
# Out:
# 'python\nimport numpy as np\nimport matplotlib.pyplot as plt\nn=10\np=0.5\nx=np.random.binomial(n,p,1000)\nplt.hist(x,bins=10)\nplt.show()'

# %%
#8 Generate multiple samples from a non-normal distribution and implement the Central Limit Theorem using Python.
'''python
import numpy as np
import matplotlib.pyplot as plt
samples = np.random.normal(loc=0, scale=1, size=(1000, 100))
sample_means = np.mean(samples, axis=1)
plt.hist(sample_means, bins=10)
plt.show()'''
# Out:
# 'python\nimport numpy as np\nimport matplotlib.pyplot as plt\nsamples = np.random.normal(loc=0, scale=1, size=(1000, 100))\nsample_means = np.mean(samples, axis=1)\nplt.hist(sample_means, bins=10)\nplt.show()'

# %%
#9 Write a python function to calculate and visualize the confidence interval for a sample mean.
'''python
import numpy as np
import matplotlib.pyplot as plt
def confidence_interval(data, confidence=0.95):
  mean = np.mean(data)
  std = np.std(data)
  n = len(data)
  intereval=stats.t.interval(confidence, n-1, loc=mean, scale=std/np.sqrt(n))
  return interval

  data = np.array([1,2,3,4,5])
  interval = confidence_interval(data)
  print(interval)
  plt.hist(data, bins=10)
  plt.axvline(interval[0], color='r')
  plt.axvline(interval[1], color='r')
  plt.show()'''
# Out:
# "python\nimport numpy as np\nimport matplotlib.pyplot as plt\ndef confidence_interval(data, confidence=0.95):\n  mean = np.mean(data)\n  std = np.std(data)\n  n = len(data)\n  intereval=stats.t.interval(confidence, n-1, loc=mean, scale=std/np.sqrt(n))\n  return interval\n\n  data = np.array([1,2,3,4,5])\n  interval = confidence_interval(data)\n  print(interval)\n  plt.hist(data, bins=10)\n  plt.axvline(interval[0], color='r')\n  plt.axvline(interval[1], color='r')\n  plt.show()"

# %%
#10 Perform a chi-square goodness of fit test using python to compare observed and expected distributions and explain the outome.
'''python
import numpy as np
from scipy.stats import chisquare
observed = np.array([1,2,3,4,5])
expected = np.array([1,2,3,4,5])
chi2,p_value=chisquare(observed,expected)
print("chi2:",chi2)
print("p_value:",p_value)
if p_value<0.05:
    print("reject null hypothesis")
    else:
        print("fail to reject null hypothesis")'''
# Out:
# 'python\nimport numpy as np\nfrom scipy.stats import chisquare\nobserved = np.array([1,2,3,4,5])\nexpected = np.array([1,2,3,4,5])\nchi2,p_value=chisquare(observed,expected)\nprint("chi2:",chi2)\nprint("p_value:",p_value)\nif p_value<0.05:\n    print("reject null hypothesis")\n    else:\n        print("fail to reject null hypothesis")'
